# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df['NA_Sales'].sum()
# Out:
# 4327.650000000001

# %%
df['EU_Sales'].sum()
# Out:
# 2406.69

# %%
sales_amount = df.groupby('Name')['JP_Sales'].sum()
sales_amount.sort_values()
# Out:
# Name
# Kameo: Elements of Power                   0.00
# The Da Vinci Code                          0.00
# Kurupoto Cool Cool Stars                   0.00
# Triple Crown Championship Snowboarding     0.00
# Kurt Warner's Arena Football Unleashed     0.00
#                                           ...
# Pokemon Diamond/Pokemon Pearl              6.04
# New Super Mario Bros.                      6.50
# Super Mario Bros.                          6.96
# Pokemon Gold/Pokemon Silver                7.20
# Pokemon Red/Pokemon Blue                  10.22
# Name: JP_Sales, Length: 11325, dtype: float64

# %%
# Nintendo has the highest sale in Europe
# Same in Japan, north America and globaly 
# In other regions Electronic Arts has the highest sale

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='JP_Sales', y='Genre', data= df, ci=None)

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='EU_Sales', y='Genre', data= df, ci=None)

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Global_Sales', y='Genre', data= df, ci=None)

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Other_Sales', y='Genre', data= df, ci=None)

# %%
import numpy as np
plt.figure(figsize=(15,6))
sns.lmplot(x="Year", y="EU_Sales", data=df, hue='Genre', fit_reg= False, height=12, scatter_kws={"s": 100})

# %%
plt.figure(figsize = (15,15))
plt.bar(df["Year"].value_counts().index, df["Year"].value_counts())
plt.title("number of games produced by year")
plt.show()

# %%
df["Year"].value_counts().index
df["Year"].value_counts()
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
x = df['Genre'].value_counts().index
y = df['Genre'].value_counts()
y
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.barplot(x=y, y=x, data= df, ci=None)
plt.title('Number of games Produced by Genre')
# Out:
# Text(0.5, 1.0, 'Number of games Produced by Genre')
