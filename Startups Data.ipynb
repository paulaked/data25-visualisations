# %%
import numpy as np
import pandas as pd

# %%
startup_data = pd.read_csv(r'C:\Users\lizzi\OneDrive\Desktop\Sparta\ks-projects-201801.csv')

# %%
startup_data.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
startup_data.isnull().sum()
# Out:
# ID                     0
# name                   4
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3797
# usd_pledged_real       0
# usd_goal_real          0
# dtype: int64

# %%
del startup_data['usd pledged']

# %%
startup_data.isnull().sum()
# Out:
# ID                  0
# name                4
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
startup_data[startup_data['name'].isna()]
# Out:
#                 ID name        category main_category currency    deadline  \
# 166851  1848699072  NaN  Narrative Film  Film & Video      USD  2012-02-29
# 307234   634871725  NaN     Video Games         Games      GBP  2013-01-06
# 309991   648853978  NaN  Product Design        Design      USD  2016-07-18
# 338931   796533179  NaN        Painting           Art      USD  2011-12-05
#
#             goal             launched  pledged      state  backers country  \
# 166851  200000.0  2012-01-01 12:35:31    100.0     failed        1      US
# 307234    2000.0  2012-12-19 23:57:48    196.0     failed       12      GB
# 309991    2500.0  2016-06-18 05:01:47      0.0  suspended        0      US
# 338931   35000.0  2011-11-06 23:55:55    220.0     failed        5      US
#
#         usd_pledged_real  usd_goal_real
# 166851            100.00      200000.00
# 307234            316.05        3224.97
# 309991              0.00        2500.00
# 338931            220.00       35000.00

# %%
blanks = startup_data[startup_data['name'].isna()]

# %%
del blanks

# %%
startup_data.isnull().sum()
# Out:
# ID                  0
# name                4
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
startup_data = startup_data.drop(blanks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/3737087973.py in <module>
# ----> 1 startup_data = startup_data.drop(blanks)
#
# NameError: name 'blanks' is not defined

# %%
startup_data = startup_data.drop(166851)

# %%
startup_data.isnull().sum()
# Out:
# ID                  0
# name                3
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
startup_data = startup_data.drop(307234, 309991, 338931)
# Out:
# C:\Users\lizzi\AppData\Local\Temp/ipykernel_24248/43957161.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   startup_data = startup_data.drop(307234, 309991, 338931)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/43957161.py in <module>
# ----> 1 startup_data = startup_data.drop(307234, 309991, 338931)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
startup_data = startup_data.drop(307234)

# %%
startup_data = startup_data.drop(309991)

# %%
startup_data = startup_data.drop(338931)

# %%
startup_data.isnull().sum()
# Out:
# ID                  0
# name                0
# category            0
# main_category       0
# currency            0
# deadline            0
# goal                0
# launched            0
# pledged             0
# state               0
# backers             0
# country             0
# usd_pledged_real    0
# usd_goal_real       0
# dtype: int64

# %%
startup_data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
import matplotlib as plt

# %%
startup_data.scatter('pledged', 'backers')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/1943676437.py in <module>
# ----> 1 startup_data.scatter('pledged', 'backers')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
x = startup_data['pledged']
x
# Out:
# 0            0.0
# 1         2421.0
# 2          220.0
# 3            1.0
# 4         1283.0
#            ...
# 378656      25.0
# 378657     155.0
# 378658      20.0
# 378659     200.0
# 378660     524.0
# Name: pledged, Length: 378657, dtype: float64

# %%
y = startup_data['backers']
plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/2808969828.py in <module>
#       1 y = startup_data['backers']
# ----> 2 plt.scatter(x, y)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\__init__.py in __getattr__(name)
#     220         if name in props:
#     221             return props[name].__get__(instance)
# --> 222         raise AttributeError(
#     223             f"module {cls.__module__!r} has no attribute {name!r}")
#     224
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
plt.set(xlim=(0,1.25), ylim=(0,100000))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/3322430791.py in <module>
# ----> 1 plt.set(xlim=(0,1.25), ylim=(0,100000))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set'

# %%
graph1 = plt.scatter(x,y)
graph1.set(xlim=(0,1.25), ylim=(0,100000))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/3453572697.py in <module>
#       1 graph1 = plt.scatter(x,y)
# ----> 2 graph1.set(xlim=(0,1.25), ylim=(0,100000))
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py in <lambda>(self, **kwargs)
#     114             return
#     115
# --> 116         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     117         cls.set.__name__ = "set"
#     118         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1162         # module.
#    1163         kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1164         return self.update(kwargs)
#    1165
#    1166     @contextlib.contextmanager
#
# ...

# %%
graph1 = plt.scatter(x,y)

# %%
graph1 = plt.scatter(x,y,)

plt.ylim=(100)

# %%
startup_data['state']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'failed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/293372305.py in <module>
# ...

# %%
failed = startup_data['state']=='failed'

# %%
failed
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 378656    False
# 378657     True
# 378658     True
# 378659     True
# 378660     True
# Name: state, Length: 378657, dtype: bool

# %%
cancelled = startup_data['state']=='canceled'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/250237040.py in <module>
# ----> 1 failed(True).count()
#
# TypeError: 'Series' object is not callable

# %%
np.where(failed)[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/1970584673.py in <module>
# ----> 1 np.where(failed)[1]
#
# IndexError: tuple index out of range

# %%
graph1

# %%
graph1 = plt.scatter(x,y)

# %%
startup_data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
startup_data.groupby('main_category').count()
# Out:
#                   ID   name  category  currency  deadline   goal  launched  \
# main_category
# Art            28152  28152     28152     28152     28152  28152     28152
# Comics         10819  10819     10819     10819     10819  10819     10819
# Crafts          8809   8809      8809      8809      8809   8809      8809
# Dance           3768   3768      3768      3768      3768   3768      3768
# Design         30069  30069     30069     30069     30069  30069     30069
# Fashion        22816  22816     22816     22816     22816  22816     22816
# Film & Video   63584  63584     63584     63584     63584  63584     63584
# Food           24602  24602     24602     24602     24602  24602     24602
# Games          35230  35230     35230     35230     35230  35230     35230
# Journalism      4755   4755      4755      4755      4755   4755      4755
# Music          51918  51918     51918     51918     51918  51918     51918
# ...

# %%
y2 = startup_data.groupby('main_category').count()

# %%
x2 = startup_data['main_category']

# %%
startup_data.plot.bar(x2, y2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/1461951257.py in <module>
# ----> 1 startup_data.plot.bar(x2, y2)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
# ...

# %%
startup_data.groupby('main_category').count()
# Out:
#                   ID   name  category  currency  deadline   goal  launched  \
# main_category
# Art            28152  28152     28152     28152     28152  28152     28152
# Comics         10819  10819     10819     10819     10819  10819     10819
# Crafts          8809   8809      8809      8809      8809   8809      8809
# Dance           3768   3768      3768      3768      3768   3768      3768
# Design         30069  30069     30069     30069     30069  30069     30069
# Fashion        22816  22816     22816     22816     22816  22816     22816
# Film & Video   63584  63584     63584     63584     63584  63584     63584
# Food           24602  24602     24602     24602     24602  24602     24602
# Games          35230  35230     35230     35230     35230  35230     35230
# Journalism      4755   4755      4755      4755      4755   4755      4755
# Music          51918  51918     51918     51918     51918  51918     51918
# ...

# %%
y2 = np.array([28152, 10819, 8809, 3768, 30069, 22816, 63584, 24602, 35230, 4755, 51918, 10779, 39874, 32569, 10913])

# %%
x2 = np.array(['Comics', 'Crafts', 'Dance', 'Design', 'Fashion', 'Film & Video', 'Food', 'Games', 'Journalism', 'Music', 'Photography', 'Publishing', 'Technology', 'Theater'])

# %%
startup_data.plot.bar(x2, y2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/1461951257.py in <module>
# ----> 1 startup_data.plot.bar(x2, y2)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
# ...

# %%
plt.bar(x2, y2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/4130857050.py in <module>
# ----> 1 plt.bar(x2, y2)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
# ...

# %%
y2 = np.array([28152, 10819, 8809, 3768, 30069, 22816, 63584, 24602, 35230, 4755, 51918, 10779, 39874, 32569, 10913])
x2 = np.array(['Comics', 'Crafts', 'Dance', 'Design', 'Fashion', 'Film & Video', 'Food', 'Games', 'Journalism', 'Music', 'Photography', 'Publishing', 'Technology', 'Theater'])
plt.bar(x2, y2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/3816500535.py in <module>
#       1 y2 = np.array([28152, 10819, 8809, 3768, 30069, 22816, 63584, 24602, 35230, 4755, 51918, 10779, 39874, 32569, 10913])
#       2 x2 = np.array(['Comics', 'Crafts', 'Dance', 'Design', 'Fashion', 'Film & Video', 'Food', 'Games', 'Journalism', 'Music', 'Photography', 'Publishing', 'Technology', 'Theater'])
# ----> 3 plt.bar(x2, y2)
#       4 plt.show()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
# ...
