# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
#data = [10,20,30]
#index_val = ['year1','year2','year3','year4','year5']

#ser1 = pd.Series(data, index=index_val)

ser1 = pd.Series([10, 20 ,30, 40, 50], index=['year1','year2','year3','year4','year5'])
#ser1.index = ['a', 'b', 'c', 'd', 'e']
ser1
# Out:
# year1    10
# year2    20
# year3    30
# year4    40
# year5    50
# dtype: int64

# %%
ser1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser1.dtype
# Out:
# dtype('int64')

# %%
ser1['year1']
# Out:
# 10

# %%
ser1[0]
# Out:
# 10

# %%
10 in ser1 #false because not in index
# Out:
# False

# %%
ser1[ser1 > 20]
# Out:
# year3    30
# year4    40
# year5    50
# dtype: int64

# %%
ser1[ser1 == 10]
# Out:
# year1    10
# dtype: int64

# %%
ser1[[True,False,False,False,False]] #returns value in true position
# Out:
# year1    10
# dtype: int64

# %%
data = [['John', 20],['Beth', 23], ['Chole', 41]]

df = DataFrame(data, columns=['Name','Score'])
df
# Out:
#     Name  Score
# 0   John     20
# 1   Beth     23
# 2  Chole     41

# %%
datadic = [{'Name': 'John', 'Score': 20},{'Name': 'Beth', 'Score': 23}, {'Name': 'Chole', 'Score': 41}]

df = DataFrame(datadic)
df
# Out:
#     Name  Score
# 0   John     20
# 1   Beth     23
# 2  Chole     41

# %%
east = Series([1000,1200,3400], index=[2016,2017,2018])
west = Series([1000,1200,3400,4500,3400], index=[2016,2017,2018,2019,2020])
east
# Out:
# 2016    1000
# 2017    1200
# 2018    3400
# dtype: int64

# %%
west
# Out:
# 2016    1000
# 2017    1200
# 2018    3400
# 2019    4500
# 2020    3400
# dtype: int64

# %%
df_regions = DataFrame({'East': east, 'West': west})
df_regions
# Out:
#         East  West
# 2016  1000.0  1000
# 2017  1200.0  1200
# 2018  3400.0  3400
# 2019     NaN  4500
# 2020     NaN  3400

# %%
df_regions.dropna()
df_regions.fillna(method='ffill') #doesnt reasign original data frame
df_regions.interpolate() #doesnt work for non linear movement or data that isnt related
# Out:
#         East  West
# 2016  1000.0  1000
# 2017  1200.0  1200
# 2018  3400.0  3400
# 2019  3400.0  4500
# 2020  3400.0  3400

# %%
df_regions['North'] = np.nan
df_regions['North'] = [2300,2300,4500,5600,np.nan]
df_regions
# Out:
#         East  West   North
# 2016  1000.0  1000  2300.0
# 2017  1200.0  1200  2300.0
# 2018  3400.0  3400  4500.0
# 2019     NaN  4500  5600.0
# 2020     NaN  3400     NaN

# %%
df_regions.dropna(thresh=2)
# Out:
#         East  West   North
# 2016  1000.0  1000  2300.0
# 2017  1200.0  1200  2300.0
# 2018  3400.0  3400  4500.0
# 2019     NaN  4500  5600.0

# %%
iris = pd.read_csv("C:/Users/\micha/\Desktop/\Sparta_Data_Engineering/\Other/\Iris.csv",sep=',',header='infer') #default sep&header
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.head() #default first 5 rows
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
spec = iris.groupby('variety')
spec

# %%
for i in spec:
    print(i)
# Out:
# ('Setosa',     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
spec.describe()
# Out:
#            sepal.length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# variety
# Setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal.width         ... petal.length      petal.width         \
#                  count   mean  ...          75%  max       count   mean
# variety                        ...
# Setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# Versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# variety
# Setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# Versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# Virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
setosa = iris[iris['variety'] == 'Setosa']
setosa
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %% [markdown]
# # Q1 - Add a rank column to the iris DataFrame, ranking the petal length in an ascending order

# %%
irisRank = iris
irisRank['Rank'] = irisRank['petal.length'].rank()
irisRank.sort_values('petal.length', inplace = True)
irisRank.head(10)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety  Rank
# 22           4.6          3.6           1.0          0.2  Setosa   1.0
# 13           4.3          3.0           1.1          0.1  Setosa   2.0
# 14           5.8          4.0           1.2          0.2  Setosa   3.5
# 35           5.0          3.2           1.2          0.2  Setosa   3.5
# 38           4.4          3.0           1.3          0.2  Setosa   8.0
# 36           5.5          3.5           1.3          0.2  Setosa   8.0
# 2            4.7          3.2           1.3          0.2  Setosa   8.0
# 40           5.0          3.5           1.3          0.3  Setosa   8.0
# 41           4.5          2.3           1.3          0.3  Setosa   8.0
# 16           5.4          3.9           1.3          0.4  Setosa   8.0

# %%
irisRank = irisRank.drop('Rank', axis=1)

# %% [markdown]
# # Q2 - Find the mean of each column for each species

# %% [markdown]
# # a

# %%
setosa = iris[iris['variety'] == 'Setosa']
setosa.mean()
# Out:
# C:\Users\micha\AppData\Local\Temp/ipykernel_25032/345666802.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   setosa.mean()
# sepal.length    5.006
# sepal.width     3.428
# petal.length    1.462
# petal.width     0.246
# dtype: float64

# %% [markdown]
# # b

# %%
versicolor = iris[iris['variety'] == 'Versicolor']
versicolor.mean()
# Out:
# C:\Users\micha\AppData\Local\Temp/ipykernel_25032/1561749374.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   versicolor.mean()
# sepal.length    5.936
# sepal.width     2.770
# petal.length    4.260
# petal.width     1.326
# dtype: float64

# %% [markdown]
# # c

# %%
virginica = iris[iris['variety'] == 'Virginica']
virginica.mean()
# Out:
# C:\Users\micha\AppData\Local\Temp/ipykernel_25032/1274075935.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   virginica.mean()
# sepal.length    6.588
# sepal.width     2.974
# petal.length    5.552
# petal.width     2.026
# dtype: float64

# %% [markdown]
# # Q3 - Create a new DataFrame for each of the species separately - should have 3 in total, make sure each index starts at 0

# %%
setosa = iris[iris['variety'] == 'Setosa']
setosa.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
versicolor = iris[iris['variety'] == 'Versicolor']
versicolor.reset_index(drop=True).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 0           7.0          3.2           4.7          1.4  Versicolor
# 1           6.4          3.2           4.5          1.5  Versicolor
# 2           6.9          3.1           4.9          1.5  Versicolor
# 3           5.5          2.3           4.0          1.3  Versicolor
# 4           6.5          2.8           4.6          1.5  Versicolor

# %%
virginica = iris[iris['variety'] == 'Virginica']
virginica.reset_index(drop=True).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width    variety
# 0           6.3          3.3           6.0          2.5  Virginica
# 1           5.8          2.7           5.1          1.9  Virginica
# 2           7.1          3.0           5.9          2.1  Virginica
# 3           6.3          2.9           5.6          1.8  Virginica
# 4           6.5          3.0           5.8          2.2  Virginica

# %% [markdown]
# # Q4 - Create two final DataFrames: One for the Sepal information, and one for the Petal information. This should be done on the whole dataset so that in each DataFrame we have information about all three species

# %%
sepal = iris.drop(['petal.length', 'petal.width'], axis=1)
sepal.head()
# Out:
#    sepal.length  sepal.width variety
# 0           5.1          3.5  Setosa
# 1           4.9          3.0  Setosa
# 2           4.7          3.2  Setosa
# 3           4.6          3.1  Setosa
# 4           5.0          3.6  Setosa

# %%
petal = iris.drop(['sepal.length', 'sepal.width'], axis=1)
petal.head()
# Out:
#    petal.length  petal.width variety
# 0           1.4          0.2  Setosa
# 1           1.4          0.2  Setosa
# 2           1.3          0.2  Setosa
# 3           1.5          0.2  Setosa
# 4           1.4          0.2  Setosa

# %%
sepal1 = DataFrame(iris, columns=['petal.length','petal.width','variety'])
sepal1.head()
# Out:
#    petal.length  petal.width variety
# 0           1.4          0.2  Setosa
# 1           1.4          0.2  Setosa
# 2           1.3          0.2  Setosa
# 3           1.5          0.2  Setosa
# 4           1.4          0.2  Setosa

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
plt.plot(fmri.timepoint, fmri.signal)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day',y='total_bill',data=tips,ci=None) # x and y can be swapped sns will work out which is dependant
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.bar(tips.day,tips.total_bill)
# Out:
# <BarContainer object of 244 artists>

# %%
sns.pairplot(iris,hue='variety')
