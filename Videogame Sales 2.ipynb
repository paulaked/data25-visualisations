# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
vsales_raw = pd.read_csv('https://raw.githubusercontent.com/paulaked/data25-visualisations/MattWoodburn/vgsales.csv')
vsales_raw
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vsales = vsales_raw.dropna()
vsales
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 15,8
sns.barplot(x="Platform", y="Global_Sales", data=vsales)
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Global_Sales'>

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 15,8
sns.lineplot(x="Year", y="NA_Sales", data=vsales)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='NA_Sales'>

# %%
vsales_drop = vsales.drop(['Rank','Name','Platform', 'Genre','Publisher','Other_Sales', 'Global_Sales'], axis=1)
vsales_melt = vsales_drop.melt("Year", var_name="NA_Sales&EU_Sales", value_name = "Sales")
vsales_melt
# Out:
#          Year NA_Sales&EU_Sales  Sales
# 0      2006.0          NA_Sales  41.49
# 1      1985.0          NA_Sales  29.08
# 2      2008.0          NA_Sales  15.85
# 3      2009.0          NA_Sales  15.75
# 4      1996.0          NA_Sales  11.27
# ...       ...               ...    ...
# 48868  2002.0          JP_Sales   0.00
# 48869  2003.0          JP_Sales   0.00
# 48870  2008.0          JP_Sales   0.00
# 48871  2010.0          JP_Sales   0.00
# 48872  2003.0          JP_Sales   0.00
#
# [48873 rows x 3 columns]

# %%
sns.lineplot(data=vsales_melt, x="Year", y="Sales", hue="NA_Sales&EU_Sales")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Sales'>

# %%
sns.scatterplot(data=vsales, x="NA_Sales", y="EU_Sales",)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='EU_Sales'>

# %%
sns.scatterplot(data=vsales, x="NA_Sales", y="JP_Sales",)
# Out:
# <AxesSubplot:xlabel='NA_Sales', ylabel='JP_Sales'>
