# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vgsales.csv')

# %%
aggregation_functions = {'Name' : 'first', 'Year': 'first', 'Genre': 'first', 'Publisher': 'first',
                         'NA_Sales': 'sum', 'EU_Sales': 'sum', 'JP_Sales': 'sum',
                         'Other_Sales': 'sum', 'Global_Sales': 'sum'}

# %%
aggregation_functions2 = {'Genre': 'first', 'NA_Sales': 'mean', 'EU_Sales': 'mean', 'JP_Sales': 'mean',
                         'Other_Sales': 'mean', 'Global_Sales': 'mean'}

# %%
df
# Out:
#      Rank                                         Name Platform    Year  \
# 0       1                                   Wii Sports      Wii  2006.0
# 1       2                            Super Mario Bros.      NES  1985.0
# 2       3                               Mario Kart Wii      Wii  2008.0
# 3       4                            Wii Sports Resort      Wii  2009.0
# 4       5                     Pokemon Red/Pokemon Blue       GB  1996.0
# ..    ...                                          ...      ...     ...
# 495   496                   Sonic Mega Collection Plus      PS2  2004.0
# 496   497                       Sega Superstars Tennis     X360  2008.0
# 497   498  World Soccer Winning Eleven 7 International      PS2  2003.0
# 498   499                  Need for Speed: Most Wanted      PS3  2012.0
# 499   500                             Hot Shots Golf 3      PS2  2001.0
#
#             Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df = df.iloc[:500,]

# %%
df
# Out:
#      Rank                                         Name Platform    Year  \
# 0       1                                   Wii Sports      Wii  2006.0
# 1       2                            Super Mario Bros.      NES  1985.0
# 2       3                               Mario Kart Wii      Wii  2008.0
# 3       4                            Wii Sports Resort      Wii  2009.0
# 4       5                     Pokemon Red/Pokemon Blue       GB  1996.0
# ..    ...                                          ...      ...     ...
# 495   496                   Sonic Mega Collection Plus      PS2  2004.0
# 496   497                       Sega Superstars Tennis     X360  2008.0
# 497   498  World Soccer Winning Eleven 7 International      PS2  2003.0
# 498   499                  Need for Speed: Most Wanted      PS3  2012.0
# 499   500                             Hot Shots Golf 3      PS2  2001.0
#
#             Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ea = df[df['Publisher'] == 'Electronic Arts'].reset_index(drop = True)
ea2 = ea.groupby('Name').aggregate(aggregation_functions)
ea2
# Out:
#                                                                                         Name  \
# Name
# 007: Tomorrow Never Dies                                            007: Tomorrow Never Dies
# Battlefield 3                                                                  Battlefield 3
# Battlefield 4                                                                  Battlefield 4
# Battlefield: Bad Company 2                                        Battlefield: Bad Company 2
# EA Sports Active                                                            EA Sports Active
# FIFA 12                                                                              FIFA 12
# FIFA 14                                                                              FIFA 14
# FIFA 15                                                                              FIFA 15
# FIFA 16                                                                              FIFA 16
# ...

# %%
av = df[df['Publisher'] == 'Activision'].reset_index(drop = True)
av2 = av.groupby('Name').aggregate(aggregation_functions)
av2.groupby('Global_Sales').first()
# Out:
#                                                      Name    Year  \
# Global_Sales
# 3.05                                        Kung Fu Panda  2008.0
# 3.13                                           Spider-Man  2000.0
# 3.27                            True Crime: Streets of LA  2003.0
# 3.41                                         Spider-Man 2  2004.0
# 3.48                                 Guitar Hero: On Tour  2008.0
# 3.65                              Guitar Hero: World Tour  2008.0
# 3.67                             Tony Hawk's Pro Skater 4  2002.0
# 3.78          LEGO Indiana Jones: The Original Adventures  2008.0
# 3.90                              Tony Hawk's Underground  2003.0
# 4.09               World of Warcraft: The Burning Crusade  2007.0
# 4.21                       Warcraft II: Tides of Darkness  1995.0
# 4.41                             Tony Hawk's Pro Skater 3  2001.0
# 4.48                                Spider-Man: The Movie  2002.0
# ...

# %%
nin = df[df['Publisher'] == 'Nintendo'].reset_index(drop = True)
nin2 = nin.groupby('Name').aggregate(aggregation_functions)
nin2.groupby('Global_Sales').last()
# Out:
#                                               Name    Year       Genre  \
# Global_Sales
# 2.92                       WarioWare: Smooth Moves  2006.0      Puzzle
# 2.94                                  Wave Race 64  1996.0      Racing
# 2.96                        Kirby Super Star Ultra  2008.0    Platform
# 2.98          Animal Crossing: Happy Home Designer  2015.0  Simulation
# 2.99                                      Star Fox  1993.0     Shooter
# ...                                            ...     ...         ...
# 33.00                            Wii Sports Resort  2009.0      Sports
# 35.82                               Mario Kart Wii  2008.0      Racing
# 35.84                                       Tetris  1989.0      Puzzle
# 45.31                            Super Mario Bros.  1985.0    Platform
# 82.74                                   Wii Sports  2006.0      Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Global_Sales
# ...

# %%
tt = df[df['Publisher'] == 'Take-Two Interactive'].reset_index(drop = True)
tt2 = tt.groupby('Name').aggregate(aggregation_functions)
tt2.groupby('Global_Sales').first()
# Out:
#                                                 Name    Year         Genre  \
# Global_Sales
# 3.00                                        NBA 2K13  2012.0        Sports
# 3.07                                   Borderlands 2  2012.0       Shooter
# 3.23                                      L.A. Noire  2011.0     Adventure
# 3.31                                       Max Payne  2001.0       Shooter
# 3.42                              Grand Theft Auto 2  1998.0        Action
# 3.44                                     Borderlands  2009.0       Shooter
# 3.66                    Midnight Club 3: DUB Edition  2005.0        Racing
# 3.85                                        NBA 2K16  2015.0        Sports
# 4.10                                  Carnival Games  2007.0          Misc
# 4.39                  The Elder Scrolls IV: Oblivion  2006.0  Role-Playing
# 5.08             Grand Theft Auto: Vice City Stories  2006.0        Action
# ...

# %%
sy = df[df['Publisher'] == 'Sony Computer Entertainment'].reset_index(drop = True)
sy2 = sy.groupby('Name').aggregate(aggregation_functions)
sy2.groupby('Global_Sales').first()
# Out:
#                                                 Name    Year         Genre  \
# Global_Sales
# 2.89                                Hot Shots Golf 3  2001.0        Sports
# 2.94                       SOCOM II: U.S. Navy SEALs  2003.0       Shooter
# 3.02                                      Killzone 2  2009.0       Shooter
# 3.12                                      Heavy Rain  2010.0     Adventure
# 3.19                   God of War: Chains of Olympus  2008.0        Action
# 3.24                                          Tekken  1995.0      Fighting
# 3.27                              Gran Turismo (PSP)  2009.0        Racing
# 3.33                                 Ratchet & Clank  2002.0      Platform
# 3.39                                      Crash Bash  2000.0          Misc
# 3.42                               LittleBigPlanet 2  2011.0      Platform
# 3.52                          Spyro 2: Ripto's Rage!  1999.0      Platform
# ...

# %%
bs = df[df['Publisher'] == 'Bethesda Softworks'].reset_index(drop = True)
bs2 = bs.groupby('Name').aggregate(aggregation_functions)
bs2.groupby('Global_Sales').first()
# Out:
#                                      Name    Year         Genre  \
# Global_Sales
# 7.25                   Fallout: New Vegas  2010.0  Role-Playing
# 8.97                            Fallout 3  2008.0  Role-Playing
# 11.05                           Fallout 4  2015.0  Role-Playing
# 19.28         The Elder Scrolls V: Skyrim  2011.0  Role-Playing
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Global_Sales
# 7.25          Bethesda Softworks      4.17      2.14      0.14         0.80
# 8.97          Bethesda Softworks      5.54      2.23      0.16         1.03
# 11.05         Bethesda Softworks      4.92      4.41      0.25         1.47
# 19.28         Bethesda Softworks      8.73      7.66      0.35         2.54

# %%
ub = df[df['Publisher'] == 'Ubisoft'].reset_index(drop = True)
ub2 = ub.groupby('Name').aggregate(aggregation_functions)
ub2
# Out:
#                                                             Name    Year  \
# Name
# Assassin's Creed                                Assassin's Creed  2007.0
# Assassin's Creed II                          Assassin's Creed II  2009.0
# Assassin's Creed III                        Assassin's Creed III  2012.0
# Assassin's Creed IV: Black Flag  Assassin's Creed IV: Black Flag  2013.0
# Assassin's Creed Syndicate            Assassin's Creed Syndicate  2015.0
# Assassin's Creed: Brotherhood      Assassin's Creed: Brotherhood  2010.0
# Assassin's Creed: Revelations      Assassin's Creed: Revelations  2011.0
# Assassin's Creed: Unity                  Assassin's Creed: Unity  2014.0
# Far Cry 3                                              Far Cry 3  2012.0
# Far Cry 4                                              Far Cry 4  2014.0
# Just Dance                                            Just Dance  2009.0
# Just Dance 2                                        Just Dance 2  2010.0
# ...

# %%
sns.barplot(x='Name', y='Global_Sales', data = ub2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Global_Sales'>

# %%
rp = df[df['Genre'] == 'Role-Playing'].reset_index(drop = True)
rp
# Out:
#     Rank                                               Name Platform    Year  \
# 0      5                           Pokemon Red/Pokemon Blue       GB  1996.0
# 1     13                        Pokemon Gold/Pokemon Silver       GB  1999.0
# 2     21                      Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 3     26                      Pokemon Ruby/Pokemon Sapphire      GBA  2002.0
# 4     27                        Pokemon Black/Pokemon White       DS  2010.0
# 5     31            Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# 6     33                                Pokemon X/Pokemon Y      3DS  2013.0
# 7     50          Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014.0
# 8     59                  Pokemon FireRed/Pokemon LeafGreen      GBA  2004.0
# 9     67                                  Final Fantasy VII       PS  1997.0
# 10    76                        The Elder Scrolls V: Skyrim     X360  2011.0
# ...

# %%
gn = df.groupby('Genre').aggregate(aggregation_functions2)
gn
# Out:
#                      Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action              Action  2.525000  1.729340  0.370755     0.686226
# Adventure        Adventure  2.451250  1.412500  0.580000     0.405000
# Fighting          Fighting  2.299167  1.117500  0.902917     0.327917
# Misc                  Misc  2.978837  2.000698  0.694884     0.569767
# Platform          Platform  4.128596  1.779649  1.286491     0.415789
# Puzzle              Puzzle  4.310909  1.638182  1.674545     0.339091
# Racing              Racing  3.274118  2.408235  0.987353     0.869706
# Role-Playing  Role-Playing  2.526207  1.738276  2.182414     0.431207
# Shooter            Shooter  3.712500  1.888421  0.162368     0.646579
# Simulation      Simulation  2.171053  2.238421  1.014737     0.452105
# Sports              Sports  2.729661  2.619492  0.494237     0.863898
# Strategy          Strategy  2.344000  1.562000  0.464000     0.268000
#
#               Global_Sales
# Genre
# ...

# %%
sns.barplot(x = 'Genre', y = 'Global_Sales', data = gn)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Global_Sales'>

# %%
sns.barplot(x = 'Name', y = 'Global_Sales', data = bs2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Global_Sales'>

# %%
sns.barplot(x = 'Genre', y = 'EU_Sales', data = gn)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='EU_Sales'>

# %%
sns.barplot(x = 'Genre', y = 'JP_Sales', data = gn)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='JP_Sales'>

# %%
sns.barplot(x = 'Genre', y = 'NA_Sales', data = gn)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='NA_Sales'>
